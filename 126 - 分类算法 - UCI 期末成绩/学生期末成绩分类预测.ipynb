# %% [markdown]
# # 数据集链接
#
# https://archive.ics.uci.edu/ml/datasets/Higher+Education+Students+Performance+Evaluation+Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
data = pd.read_csv('DATA.csv', sep=';')
target = data['GRADE']

# %%
data
# Out:
#      STUDENT ID  1  2  3  4  5  6  7  8  9  ...  23  24  25  26  27  28  29  \
# 0      STUDENT1  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   1   2   1
# 1      STUDENT2  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   3   2   2
# 2      STUDENT3  2  2  2  3  2  2  2  2  4  ...   1   1   2   2   1   1   2
# 3      STUDENT4  1  1  1  3  1  2  1  2  1  ...   1   2   3   2   2   1   3
# 4      STUDENT5  2  2  1  3  2  2  1  3  1  ...   2   1   2   2   2   1   2
# ..          ... .. .. .. .. .. .. .. .. ..  ...  ..  ..  ..  ..  ..  ..  ..
# 140  STUDENT141  2  1  2  3  1  1  2  1  1  ...   1   1   2   1   2   1   3
# 141  STUDENT142  1  1  2  4  2  2  2  1  4  ...   1   1   3   2   2   1   5
# 142  STUDENT143  1  1  1  4  2  2  2  1  1  ...   1   1   3   3   2   1   4
# 143  STUDENT144  2  1  2  4  1  1  1  5  2  ...   2   1   2   1   2   1   5
# 144  STUDENT145  1  1  1  5  2  2  2  3  1  ...   2   1   3   2   3   1   5
#
#      30  COURSE ID  GRADE
# 0     1          1      1
# ...

# %%
# 各个特征值对结果的相关性（皮卡尔相关系数-正相关性）
arr_pear = []
for x in data.columns[1:-1]:
    r = pearsonr(x=data.loc[:, x], y=target)
    arr_pear.append(r)
    print(r)
# Out:
# (-0.09525123761290633, 0.2544351087786128)
# (0.33553323473741187, 3.697125971669931e-05)
# (0.10482107449440753, 0.20957024312224123)
# (0.023962857403039484, 0.7748056128862699)
# (0.16744522538140935, 0.04410491747862158)
# (-0.06299282951008883, 0.4516200361537235)
# (-0.05177767722955321, 0.5362427919077183)
# (-0.1663515198359841, 0.045526576046061994)
# (-0.1562892128242112, 0.060485804979856804)
# (0.023682592315124068, 0.7773703121981144)
# (0.06631827593243016, 0.42804642890296213)
# (0.06350415926925557, 0.44794872219370124)
# (0.0844699682091858, 0.31242043190876406)
# (0.06637856535141001, 0.4276256930268406)
# (-0.03074707591313411, 0.7135249139934982)
# (-0.04426779877204802, 0.5970131979509268)
# (-0.03306546128830172, 0.6929736937571008)
# (0.1956170690745464, 0.01837458495146757)
# (0.0031888330229986896, 0.9696347515924754)
# (-0.1847625149967909, 0.026096701921325547)
# (-0.20327253099396728, 0.014198639820148651)
# (-0.13956386584016975, 0.09408535991644025)
# ...

# %%
index = ['学生年龄', '性别', '高中毕业类型', '奖学金类型', '附加工作', '定期的艺术或体育活动', '您是否有伴侣', '总工资（如果有）', '到大学的交通', '塞浦路斯住宿类型', '母亲的教育', '父亲的教育', '姐妹/兄弟人数（如果有）', '父母身份', '母亲的职业', '父亲职业', '每周学习时间', '阅读频率（非科学书籍/期刊）', '阅读频率（科学书籍/期刊）', '参加与部门相关的研讨会/会议', '您的项目/活动对您成功的影响', '出席上课', '准备期中考试1', '准备期中考试2', '准备期中考试', '课堂听力', '讨论提高了我在课程中的兴趣和成功', '翻转课堂', '累积成绩上学期平均分', '毕业时预期累积平均绩点', '课程 ID']
arr_pear = pd.DataFrame(data=arr_pear, index=index)
arr_pear.sort_values(by=0, inplace=True)
arr_pear
# Out:
#                          0         1
# 您的项目/活动对您成功的影响   -0.203273  0.014199
# 参加与部门相关的研讨会/会议   -0.184763  0.026097
# 总工资（如果有）         -0.166352  0.045527
# 到大学的交通           -0.156289  0.060486
# 出席上课             -0.139564  0.094085
# 学生年龄             -0.095251  0.254435
# 定期的艺术或体育活动       -0.062993  0.451620
# 您是否有伴侣           -0.051778  0.536243
# 父亲职业             -0.044268  0.597013
# 每周学习时间           -0.033065  0.692974
# 母亲的职业            -0.030747  0.713525
# 阅读频率（科学书籍/期刊）     0.003189  0.969635
# 准备期中考试1           0.014638  0.861280
# 塞浦路斯住宿类型          0.023683  0.777370
# 奖学金类型             0.023963  0.774806
# 准备期中考试            0.044862  0.592090
# 父亲的教育             0.063504  0.447949
# 母亲的教育             0.066318  0.428046
# 父母身份              0.066379  0.427626
# 准备期中考试2           0.073783  0.377791
# 姐妹/兄弟人数（如果有）      0.084470  0.312420
# 课堂听力              0.085137  0.308602
# 高中毕业类型            0.104821  0.209570
# 翻转课堂              0.110617  0.185323
# ...

# %%
plt.figure(figsize=(20, 10))
plt.scatter(x=arr_pear.index, y=arr_pear.iloc[:, 0], marker='+', color='r', label='皮卡尔逊相关系数')
plt.scatter(x=arr_pear.index, y=arr_pear.iloc[:, 1], marker='o', color='b', label=' p-value')
plt.axhline(y=-0.5, c='b', linestyle='-.', alpha=0.5)
plt.axhline(y=-0.3, c='b', linestyle='-.', alpha=0.5)
plt.axhline(y=-0.1, c='b', linestyle='-.', alpha=0.5)
plt.axhline(y=0.0, c='black', linestyle='--', alpha=1.0)
plt.axhline(y=0.1, c='r', linestyle='-.', alpha=0.5)
plt.axhline(y=0.3, c='r', linestyle='-.', alpha=0.5)
plt.axhline(y=0.5, c='r', linestyle='-.', alpha=0.5)
plt.legend()
plt.title('各种特征值对最终考试成绩的影响（皮卡尔相关系数）\n高等教育学生成绩评估', fontsize=20)
plt.xticks(rotation=70)
plt.xlabel('影响因素', fontsize=20)
plt.ylabel('皮卡尔逊相关系数', fontsize=20)
plt.grid(linestyle='--', alpha=0.5)
plt.savefig('./result_pear.png')
plt.show()

# %%
data['GRADE']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 140    5
# 141    5
# 142    1
# 143    4
# 144    3
# Name: GRADE, Length: 145, dtype: int64
